# %% [markdown]
# <b>Sim Models Metadata Notebook</b><br>
#  - JSONL file to be read line-by-line for each file case.

# %% [markdown]
# <b>Libraries</b>

# %%
import json
import ast
import string
import spacy
import pandas as pd
import os
print( os.getcwd() )
# Out:
# c:\Users\jchown\projects\metadata_cleanup

# %% [markdown]
# <b>Global Variables</b>

# %%
trained_nlp = spacy.load("./mpn_nlp_model")

# %% [markdown]
# <b>Read JSONL file contents into list</b>

# %%
with open('sim_models_api_feed.json', 'rt') as file_handle:
    file_data = json.loads( file_handle.read() )

metadata_case_list = file_data['hits']

# %%
metadata_case_list[0]
# Out:
# {'jcr:path': '/content/dam/micron/global/secure/products/sim-model/modules/ddr5/mtc20f2085s1rc64bd1-thermal.zip',
#  'jcr:primaryType': 'dam:Asset',
#  'jcr:mixinTypes': ['mix:referenceable'],
#  'jcr:createdBy': 'sdanny@micron.com',
#  'jcr:created': 'Fri Jan 26 2024 20:30:22 GMT+0000',
#  'jcr:uuid': '432ca891-da31-4c4a-b600-80c3f6974162',
#  'jcr:content': {'jcr:primaryType': 'dam:AssetContent',
#   'jcr:mixinTypes': ['cq:ReplicationStatus'],
#   'mt:documentID': '432ca891-da31-4c4a-b600-80c3f6974162',
#   'cq:lastReplicationAction': 'Activate',
#   'mt:documentSupport': 'web_support',
#   'migratedFrom': 'micron-aws-s3-aem:prod/sites-dam/micron/global/secure-latest/products/sim-model/modules/ddr5/mtc20f2085s1rc64bd1-thermal.zip',
#   'cq:lastReplicatedBy': 'workflow-process-service',
#   'fmUuid': 'GUID-acedaa40-b2b5-45f7-b524-999fd31a8f7e',
#   'jcr:lastModifiedBy': 'sdanny@micron.com',
#   'mt:securityLevel': '5',
#   'cq:lastReplicated': 'Fri Aug 09 2024 09:10:38 GMT+0000',
#   'names': 'mtc20f2085s1rc64bd1-thermal.zip',
#   'mt:legacyID': '',
#   'dam:assetState': 'processed',
#   'mt:userRoles': ['B2CEXT_MTI_ADMIN', 'B2CEXT_MTI_MICRON'],
#   'jcr:lastModified': 'Fri Jan 26 2024 20:48:15 GMT+0000',
#   'fmPostProcessedAt': '2024-01-26T20:30:22.530Z|432ca891-da31-4c4a-b600-80c3f6974162|2024-01-26T20:30:22.529Z|3|0',
#   'names-2': 'mtc20f2085s1rc64bd1-thermal',
#   'mt:exportControl': 'yes',
#   'renditions': {'jcr:primaryType': 'nt:folder',
#    'jcr:createdBy': 'sdanny@micron.com',
#    'jcr:created': 'Fri Jan 26 2024 20:30:22 GMT+0000'},
#   'related': {'jcr:primaryType': 'nt:unstructured'},
#   'metadata': {'jcr:primaryType': 'nt:unstructured',
#    'jcr:mixinTypes': ['cq:Taggable'],
#    'mt:userGroupRBA': '',
#    'mt:lifecycleReview': ['5-years'],
#    'mt:rba': ['sc'],
#    'dam:extracted': 'Fri Jan 26 2024 20:48:15 GMT+0000',
#    'dc:format': 'application/zip',
#    'dc:language': '',
#    'mt:contentType': ['micron:document type-categories-subcategories/sim-model'],
#    'mt:owneremail': '',
#    'dam:FileCount': 1,
#    'dam:Content': 'MTC20F2085S1RC64BD1 (1).pdml\n',
#    'docstate': 'Draft',
#    'dam:sha1': '77ba67e97c757cac473fc7a6d62f07f0f45d6729',
#    'dam:size': 3622}}}

# %% [markdown]
# <b>Remove non-printable characters</b>

# %%
def remove_non_printable(text: str):
    return ''.join( filter(str.isprintable, str(text)) )

# %% [markdown]
# <b>Simplify text removing punctuation and reducing whitespace</b>

# %%
def simplify_text(text: str) -> str:
    if text == 'none':
        return ''
    simplified_text = str(text).translate( str.maketrans( dict.fromkeys(string.punctuation, ' ') ) )
    return ' '.join( [ text_item for text_item in simplified_text.split() if len(text_item) > 0 ] )

# %% [markdown]
# <b>Parse the subject field into a list of subject strings</b>

# %%
def parse_subject(text: str) -> str:
    try:
        text_list = ast.literal_eval(text)
    
    except Exception as _e:
        text_list = [text]
    
    output_list = list()
    for text_item in text_list:
        if text_item == 'none' or len(text_item) == 0:
            continue
        clean_text_item = simplify_text(text_item)
        output_list += [ text for text in clean_text_item.split() if len(text) > 0 ]

    unique_output_list_ordered = list()
    for text_item in output_list:
        if text_item not in unique_output_list_ordered:
            unique_output_list_ordered.append(text_item)
    
    return ' '.join(unique_output_list_ordered)

# %% [markdown]
# <b>Parse the products field into a list of product strings</b>

# %%
def parse_products(text: str) -> list:
    try:
        text_list = ast.literal_eval(text)
    
    except Exception as _e:
        text_list = [text]
    
    output_list = list()
    for text_item in text_list:
        if text_item == 'none' or len(text_item) == 0:
            continue
        partial_text_item = ' '.join( text_item.split('/')[-2:] )
        clean_text_item = simplify_text(partial_text_item)
        output_list += [ text for text in clean_text_item.split() if len(text) > 0 ]

    unique_product_list = list()
    for text_item in output_list:
        if text_item not in unique_product_list:
            unique_product_list.append(text_item)

    return unique_product_list

# %% [markdown]
# <b>Parse the doc category for AEM docs</b>

# %%
def parse_aem_doc_category(text: str, url: str) -> str:
    
    if 'data sheet' in text or 'data-sheet' in url:
        return 'data sheet'
    
    if 'technical note' in text or 'technical-note' in url:
        return 'tech note'
    
    return 'other'

# %% [markdown]
# <b>Preprocessor for NER</b>

# %%
def preprocess_ner_text(text: str) -> str:
    output_text = remove_non_printable( text.lower() )
    output_text = simplify_text(output_text)
    output_text = output_text.replace('–', ' ').replace('\r\n', '').strip()
    return output_text

# %% [markdown]
# <b>Postprocessor for NER</b>

# %%
def postprocess_ner_extracts(ner_list: list) -> list:
    if len(ner_list) < 1:
        return list()
    
    output_list = list()
    for list_item in ner_list:
        output_list += list_item.split()
    
    return output_list

# %% [markdown]
# <b>NER for MPN</b>

# %%
def ner_mpn(input_data) -> list:
    if isinstance(input_data, str):
        input_data_list = [input_data]
    elif isinstance(input_data, list):
        input_data_list = input_data
    else:
        raise ValueError("input_data argument must be str or list type!")

    mpn_list = list()
    for text in input_data_list:
        for sub_text in str(text).split():
            if len(sub_text) > 0:
                doc = trained_nlp( str(sub_text) )
                mpn_list += [ str(mpn.text).strip() for mpn in doc.ents if doc.ents and "MPN" in mpn.label_ and len(mpn.text) > 4 and mpn.text != "manufacturer" ]
    
    return mpn_list

# %% [markdown]
# <b>Rule-Based NER</b>

# %%
def rule_based_ner(input_str: str, string_rules: list) -> list:
    output_list = list()
    for string_rule in string_rules:
        if str(string_rule).lower() in str(input_str).lower():
            output_list.append( str(string_rule).lower() )
    return output_list

# %%
def rule_based_ner_data_source(input_str_dict: dict, string_rules: list) -> str:

    output_list = list()

    # MT Content Type
    split_mt_content_type = input_str_dict['mt_content_type'].split('/')
    if split_mt_content_type:
        for string_rule in string_rules:
            if string_rule in split_mt_content_type:
                output_list.append( str(string_rule).lower() )
    
    # Thermal type is also in the jcr:path.
    if 'thermal' in input_str_dict['jcr_path']:
        output_list.append('thermal')
    
    unique_output_list = list( set(output_list) )
    return ' '.join(unique_output_list)

# %%
rules_df = pd.read_excel('entity_groups.xlsx')
BU_NER_RULES = ['ebu', 'sbu', 'cnbu', 'mbu', 'cpg']
FUNCTIONAL_TECHNOLOGY_RULES = rules_df.loc[~pd.isna(rules_df['Functional Technology']), 'Functional Technology'].to_list()
MARKET_SUBSEGMENT_RULES = rules_df.loc[~pd.isna(rules_df['Segments']), 'Segments'].to_list()
PACKAGE_TYPE_RULES = rules_df.loc[~pd.isna(rules_df['Package Type']), 'Package Type'].to_list()
DENSITY_RULES = rules_df.loc[~pd.isna(rules_df['Density']), 'Density'].to_list()
PRODUCT_SERIES_RULES = rules_df.loc[~pd.isna(rules_df['Product Series']), 'Product Series'].to_list()
PROCESS_REQUIREMENT_RULES = rules_df.loc[~pd.isna(rules_df['Process Requirements']), 'Process Requirements'].to_list()
DESIGN_ID_RULES = rules_df.loc[~pd.isna(rules_df['Design ID']), 'Design ID'].to_list()
DOC_CATEGORY_RULES = ['ibis', 'verilog', 'hspice', 'spice', 's-parameter', 'simulation-model', 'hyperlynx', 'ibis-ami', 'system-verilog', 'thermal', 'sisoft',]

# %% [markdown]
# <b>Build NER Data</b>

# %%
def build_ner_data(text_list: list, method: str) -> list:
    if method == 'mpn':
        output_list = list()
        for text_item in text_list:
            output_list += postprocess_ner_extracts( ner_mpn( preprocess_ner_text(text_item) ) )
        return list( set(output_list) )

    elif method == 'bu':
        output_list = list()
        for text_item in text_list:
            output_list += postprocess_ner_extracts( rule_based_ner(preprocess_ner_text(text_item), BU_NER_RULES) )
        return list( set(output_list) )
    
    elif method == 'functional_technology':
        output_list = list()
        for text_item in text_list:
            output_list += postprocess_ner_extracts( rule_based_ner(preprocess_ner_text(text_item), FUNCTIONAL_TECHNOLOGY_RULES) )
        return list( set(output_list) )

    elif method == 'market_subsegment':
        output_list = list()
        for text_item in text_list:
            output_list += postprocess_ner_extracts( rule_based_ner(preprocess_ner_text(text_item), MARKET_SUBSEGMENT_RULES) )
        return list( set(output_list) )

    elif method == 'package_type':
        output_list = list()
        for text_item in text_list:
            output_list += postprocess_ner_extracts( rule_based_ner(preprocess_ner_text(text_item), PACKAGE_TYPE_RULES) )
        return list( set(output_list) )

    elif method == 'product_series':
        output_list = list()
        for text_item in text_list:
            output_list += postprocess_ner_extracts( rule_based_ner(preprocess_ner_text(text_item), PRODUCT_SERIES_RULES) )
        return list( set(output_list) )

    elif method == 'process_requirement':
        output_list = list()
        for text_item in text_list:
            output_list += postprocess_ner_extracts( rule_based_ner(preprocess_ner_text(text_item), PROCESS_REQUIREMENT_RULES) )
        return list( set(output_list) )

    elif method == 'design_id':
        output_list = list()
        for text_item in text_list:
            output_list += postprocess_ner_extracts( rule_based_ner(preprocess_ner_text(text_item), DESIGN_ID_RULES) )
        return list( set(output_list) )

    elif method == 'density':
        output_list = list()
        for text_item in text_list:
            output_list += postprocess_ner_extracts( rule_based_ner(preprocess_ner_text(text_item), DENSITY_RULES) )
        return list( set(output_list) )

    raise ValueError("Method of NER extraction incorrect! Must be mpn, bu, functional_technology, market_subsegment, package_type, product_series, process_requirement, or design_id!")

# %% [markdown]
# <b>TEST Metadata Cleanup</b><br>
# <code>},
#     {
#       "jcr:path": "/content/dam/micron/global/secure/products/sim-model/modules/ddr4/mta18asf2g72hz-3g2b1-ebd.zip",
#        ],
#       "jcr:created": "Fri Jan 26 2024 20:29:06 GMT+0000",
#       "jcr:uuid": "1fe3ff3f-3cdc-4bf6-ad24-d07a34c06b1e",
#         "mt:documentID": "1fe3ff3f-3cdc-4bf6-ad24-d07a34c06b1e",
#         "mt:documentSupport": "dram_support",
#         "names": "mta18asf2g72hz-3g2b1-ebd.zip",
#         "jcr:lastModified": "Mon Dec 16 2024 18:32:50 GMT+0000",
#         "names-2": "mta18asf2g72hz-3g2b1-ebd",
#         metadata":
#         "mt:rba": [
#           "cnbu"
#           ],
#           "dc:description": "MTA18ASF2G72HZ-3G2B1",
#           "mt:contentType": "micron:document type-categories-subcategories/sim-model/ibis",
#           "dam:Content": "MTA18ASF2G72HZ-3G2B1_ebd/clk_termination.JPG\nMTA18ASF2G72HZ-3G2B1_ebd/MTA18ASF2G72HZ-3G2B1.ebd\nMTA18ASF2G72HZ-3G2B1_ebd/MTA18ASF2G72HZ-3G2B1.ibs\nMTA18ASF2G72HZ-3G2B1_ebd/MTA18ASF2G72HZ-3G2B1_ebd_readme.txt\nMTA18ASF2G72HZ-3G2B1_ebd/resistor_d.ibs\nMTA18ASF2G72HZ-3G2B1_ebd/z22a.ibs\nMTA18ASF2G72HZ-3G2B1_ebd/z22a_ext_model_quality_rpt.pdf\n",
#           "dc:title": "DDR4 IBIS EBD Model"
# </code>

# %%
test_case = metadata_case_list[0]
test_case.keys()
# Out:
# dict_keys(['jcr:path', 'jcr:primaryType', 'jcr:mixinTypes', 'jcr:createdBy', 'jcr:created', 'jcr:uuid', 'jcr:content'])

# %%
print('JCR PATH: ', remove_non_printable( test_case.get('jcr:path', '') ).lower() )
print('DC:DESCRIPTION: ', test_case.get('jcr:content', {}).get('metadata', {}).get('dc:description', ''))
print('MT:CONTENTTYPE: ', test_case.get('jcr:content', {}).get('metadata', {}).get('mt:contentType', [''])[0])
print('DC:TITLE: ', test_case.get('jcr:content', {}).get('metadata', {}).get('dc:title', ''))
# Out:
# JCR PATH:  /content/dam/micron/global/secure/products/sim-model/modules/ddr5/mtc20f2085s1rc64bd1-thermal.zip
# DC:DESCRIPTION:
# MT:CONTENTTYPE:  micron:document type-categories-subcategories/sim-model
# DC:TITLE:

# %%
case_number = 0
test_clean_metadata_list = list()
for test_case in metadata_case_list:
    case_number += 1
    print( f"Working on case {case_number} of {len(metadata_case_list)}")
    test_clean_case = dict()

    # Baseline keys.
    test_clean_case['id'] = test_case.get('jcr:uuid', '')
    test_clean_case['content'] = "DE TEAM TO POPULATE!!!" # GCS path + MIME

    # jsonData construction.
    test_clean_case_jsonData = dict()

    # Core metadata fields.
    test_clean_case_jsonData['doc_type'] = 'sim-model'
    test_clean_case_jsonData['file_name'] = remove_non_printable( test_case.get('jcr:path', '') ).split('/')[-1].replace('_', '-').replace('/', '-').replace('\r\n', '')
    test_clean_case_jsonData['url'] = 'https://www.micron.com' + remove_non_printable( test_case.get('jcr:path', '') )
    test_clean_case_jsonData['pillar'] = "sales"
    test_clean_case_jsonData['language'] = "{'English': 99.0}"
    test_clean_case_jsonData['deleted'] = "no"
    test_clean_case_jsonData['author'] = remove_non_printable( str( test_case.get('jcr:createdBy', '') ).replace("['", '').replace("']", '') )
    test_clean_case_jsonData['last_modified_time'] = remove_non_printable( test_case.get('jcr:created', '') )
    test_clean_case_jsonData['last_modified_unix_time'] = "DE TEAM TO POPULATE!!!"
    test_clean_case_jsonData['title'] = remove_non_printable( test_case.get('jcr:content', {}).get('names', '') ).replace('_', '-').replace('/', '-').replace('\r\n', '')
    test_clean_case_jsonData['file_type'] = "DE TEAM TO POPULATE!!!"
    test_clean_case_jsonData['doc_id'] = remove_non_printable( test_case.get('jcr:uuid', '') ) # DE TEAM MAY NEED TO POPULATE!!!

    # Doc IDs for DPC - DE TEAM TO VALIDATE AND POPULATE WITH CORRECT INFORMATION!!!
    test_clean_case_jsonData['aem_object_id'] = remove_non_printable( test_case.get('jcr:uuid', '') )
    test_clean_case_jsonData['aem_uuid'] = remove_non_printable( test_case.get('jcr:uuid', '') )

    # Doc category    
    test_clean_case_jsonData['doc_category'] = rule_based_ner_data_source(
        {
            'mt_content_type': test_case.get('jcr:content', {}).get('metadata', {}).get('mt:contentType', [''])[0],
            'jcr_path': remove_non_printable( test_case.get('jcr:path', '') ).lower(),
        },
        DOC_CATEGORY_RULES,
    )
    # parse_aem_doc_category(
    #     simplify_text( remove_non_printable( test_case['jsonData'].get('doc_category', '') ).lower().replace(',', ' ').replace('-', ' ').replace('–', ' ').strip() ),
    #     test_case['jsonData']['url'],
    # )

    # Optional AEM metadata fields.
    test_clean_case_jsonData['description'] = ' '.join([
        simplify_text( remove_non_printable( test_case.get('jcr:content', {}).get('metadata', {}).get('dc:description', '') ).lower().replace(',', ' ').replace('-', ' ').replace('–', ' ').strip() ),
    ])
    test_clean_case_jsonData['subject'] = ' '.join([
        simplify_text( remove_non_printable( test_case.get('jcr:content', {}).get('metadata', {}).get('dc:title', '') ).lower().replace(',', ' ').replace('-', ' ').replace('–', ' ').strip() ),
        simplify_text( remove_non_printable( test_case.get('jcr:content', {}).get('metadata', {}).get('dam:Content', '')[:100] ).lower().replace(',', ' ').replace('-', ' ').replace('–', ' ').strip() ),
    ])
    test_clean_case_jsonData['products'] = simplify_text( remove_non_printable( test_case.get('jcr:content', {}).get('metadata', {}).get('dam:Content', '')[100:200] ).lower().replace(',', ' ').replace('-', ' ').replace('–', ' ').strip() )
    test_clean_case_jsonData['optional_text_field_1'] = ' '.join(['',])
    test_clean_case_jsonData['optional_text_field_2'] = ' '.join(['',])
    test_clean_case_jsonData['optional_text_field_3'] = ' '.join(['',])
    test_clean_case_jsonData['optional_text_field_4'] = ' '.join(['',])
    test_clean_case_jsonData['optional_text_field_5'] = ' '.join(['',])

    # NER metadata.
    test_clean_case_jsonData['business_unit_list'] = build_ner_data(test_case.get('jcr:content', {}).get('metadata', {}).get('mt:rba', ''), 'bu')
    test_clean_case_jsonData['market_subsegment_list'] = build_ner_data(
        [
            test_clean_case_jsonData['file_name'],
            test_clean_case_jsonData['url'],
            test_clean_case_jsonData['description'],
            test_clean_case_jsonData['subject'],
            test_clean_case_jsonData['products'],
            test_clean_case_jsonData['optional_text_field_1'],
            test_clean_case_jsonData['optional_text_field_2'],
            test_clean_case_jsonData['optional_text_field_3'],
            test_clean_case_jsonData['optional_text_field_4'],
            test_clean_case_jsonData['optional_text_field_5'],
        ],
        'market_subsegment',
    )
    test_clean_case_jsonData['mpn_list'] = build_ner_data(
        [
            test_clean_case_jsonData['file_name'],
            test_clean_case_jsonData['url'],
            test_clean_case_jsonData['description'],
            test_clean_case_jsonData['subject'],
            test_clean_case_jsonData['products'],
            test_clean_case_jsonData['optional_text_field_1'],
            test_clean_case_jsonData['optional_text_field_2'],
            test_clean_case_jsonData['optional_text_field_3'],
            test_clean_case_jsonData['optional_text_field_4'],
            test_clean_case_jsonData['optional_text_field_5'],
        ],
        'mpn',
    )
    test_clean_case_jsonData['design_id_list'] = build_ner_data(
        [
            test_clean_case_jsonData['file_name'],
            test_clean_case_jsonData['url'],
            test_clean_case_jsonData['description'],
            test_clean_case_jsonData['subject'],
            test_clean_case_jsonData['products'],
            test_clean_case_jsonData['optional_text_field_1'],
            test_clean_case_jsonData['optional_text_field_2'],
            test_clean_case_jsonData['optional_text_field_3'],
            test_clean_case_jsonData['optional_text_field_4'],
            test_clean_case_jsonData['optional_text_field_5'],
        ],
        'design_id',
    )
    test_clean_case_jsonData['functional_technology_list'] = build_ner_data(
        [
            test_clean_case_jsonData['file_name'],
            test_clean_case_jsonData['url'],
            test_clean_case_jsonData['description'],
            test_clean_case_jsonData['subject'],
            test_clean_case_jsonData['products'],
            test_clean_case_jsonData['optional_text_field_1'],
            test_clean_case_jsonData['optional_text_field_2'],
            test_clean_case_jsonData['optional_text_field_3'],
            test_clean_case_jsonData['optional_text_field_4'],
            test_clean_case_jsonData['optional_text_field_5'],
        ],
        'functional_technology',
    )
    test_clean_case_jsonData['package_type_list'] = build_ner_data(
        [
            test_clean_case_jsonData['file_name'],
            test_clean_case_jsonData['url'],
            test_clean_case_jsonData['description'],
            test_clean_case_jsonData['subject'],
            test_clean_case_jsonData['products'],
            test_clean_case_jsonData['optional_text_field_1'],
            test_clean_case_jsonData['optional_text_field_2'],
            test_clean_case_jsonData['optional_text_field_3'],
            test_clean_case_jsonData['optional_text_field_4'],
            test_clean_case_jsonData['optional_text_field_5'],
        ],
        'package_type',
    )
    test_clean_case_jsonData['density_list'] = build_ner_data(
        [
            test_clean_case_jsonData['file_name'],
            test_clean_case_jsonData['url'],
            test_clean_case_jsonData['description'],
            test_clean_case_jsonData['subject'],
            test_clean_case_jsonData['products'],
            test_clean_case_jsonData['optional_text_field_1'],
            test_clean_case_jsonData['optional_text_field_2'],
            test_clean_case_jsonData['optional_text_field_3'],
            test_clean_case_jsonData['optional_text_field_4'],
            test_clean_case_jsonData['optional_text_field_5'],
        ],
        'density',
    )
    test_clean_case_jsonData['product_series_list'] = build_ner_data(
        [
            test_clean_case_jsonData['file_name'],
            test_clean_case_jsonData['url'],
            test_clean_case_jsonData['description'],
            test_clean_case_jsonData['subject'],
            test_clean_case_jsonData['products'],
            test_clean_case_jsonData['optional_text_field_1'],
            test_clean_case_jsonData['optional_text_field_2'],
            test_clean_case_jsonData['optional_text_field_3'],
            test_clean_case_jsonData['optional_text_field_4'],
            test_clean_case_jsonData['optional_text_field_5'],
        ],
        'product_series',
    )
    test_clean_case_jsonData['process_requirement_list'] = build_ner_data(
        [
            test_clean_case_jsonData['file_name'],
            test_clean_case_jsonData['url'],
            test_clean_case_jsonData['description'],
            test_clean_case_jsonData['subject'],
            test_clean_case_jsonData['products'],
            test_clean_case_jsonData['optional_text_field_1'],
            test_clean_case_jsonData['optional_text_field_2'],
            test_clean_case_jsonData['optional_text_field_3'],
            test_clean_case_jsonData['optional_text_field_4'],
            test_clean_case_jsonData['optional_text_field_5'],
        ],
        'process_requirement',
    )

    test_clean_case['jsonData'] = test_clean_case_jsonData
    
    test_clean_metadata_list.append(test_clean_case)
# Out:
# Working on case 1 of 1093
# Working on case 2 of 1093
# Working on case 3 of 1093
# Working on case 4 of 1093
# Working on case 5 of 1093
# Working on case 6 of 1093
# Working on case 7 of 1093
# Working on case 8 of 1093
# Working on case 9 of 1093
# Working on case 10 of 1093
# Working on case 11 of 1093
# Working on case 12 of 1093
# Working on case 13 of 1093
# Working on case 14 of 1093
# Working on case 15 of 1093
# Working on case 16 of 1093
# Working on case 17 of 1093
# Working on case 18 of 1093
# Working on case 19 of 1093
# Working on case 20 of 1093
# Working on case 21 of 1093
# Working on case 22 of 1093
# Working on case 23 of 1093
# Working on case 24 of 1093
# Working on case 25 of 1093
# Working on case 26 of 1093
# Working on case 27 of 1093
# Working on case 28 of 1093
# Working on case 29 of 1093
# Working on case 30 of 1093
# Working on case 31 of 1093
# Working on case 32 of 1093
# Working on case 33 of 1093
# Working on case 34 of 1093
# Working on case 35 of 1093
# Working on case 36 of 1093
# Working on case 37 of 1093
# Working on case 38 of 1093
# Working on case 39 of 1093
# Working on case 40 of 1093
# Working on case 41 of 1093
# Working on case 42 of 1093
# Working on case 43 of 1093
# Working on case 44 of 1093
# Working on case 164 of 1093
# Working on case 165 of 1093
# Working on case 166 of 1093
# Working on case 167 of 1093
# Working on case 168 of 1093
# Working on case 169 of 1093
# Working on case 170 of 1093
# Working on case 171 of 1093
# Working on case 172 of 1093
# Working on case 173 of 1093
# Working on case 174 of 1093
# Working on case 175 of 1093
# Working on case 176 of 1093
# Working on case 177 of 1093
# Working on case 178 of 1093
# Working on case 179 of 1093
# Working on case 180 of 1093
# Working on case 181 of 1093
# Working on case 182 of 1093
# Working on case 183 of 1093
# Working on case 184 of 1093
# Working on case 185 of 1093
# Working on case 186 of 1093
# Working on case 187 of 1093
# Working on case 188 of 1093
# Working on case 189 of 1093
# Working on case 190 of 1093
# Working on case 191 of 1093
# Working on case 192 of 1093
# Working on case 193 of 1093
# Working on case 194 of 1093
# Working on case 195 of 1093
# Working on case 196 of 1093
# Working on case 197 of 1093
# Working on case 198 of 1093
# Working on case 199 of 1093
# Working on case 200 of 1093
# Working on case 201 of 1093
# Working on case 202 of 1093
# Working on case 203 of 1093
# Working on case 204 of 1093
# Working on case 205 of 1093
# Working on case 206 of 1093
# Working on case 207 of 1093
# Working on case 208 of 1093
# Working on case 209 of 1093
# Working on case 210 of 1093
# Working on case 211 of 1093
# Working on case 212 of 1093
# Working on case 213 of 1093
# Working on case 214 of 1093
# Working on case 215 of 1093
# Working on case 216 of 1093
# Working on case 217 of 1093
# Working on case 218 of 1093
# Working on case 219 of 1093
# Working on case 220 of 1093
# Working on case 221 of 1093
# Working on case 222 of 1093
# Working on case 223 of 1093
# Working on case 224 of 1093
# Working on case 225 of 1093
# Working on case 226 of 1093
# Working on case 227 of 1093
# Working on case 228 of 1093
# Working on case 229 of 1093
# Working on case 230 of 1093
# Working on case 231 of 1093
# Working on case 232 of 1093
# Working on case 233 of 1093
# Working on case 234 of 1093
# Working on case 235 of 1093
# Working on case 236 of 1093
# Working on case 237 of 1093
# Working on case 238 of 1093
# Working on case 239 of 1093
# Working on case 240 of 1093
# Working on case 241 of 1093
# Working on case 242 of 1093
# Working on case 243 of 1093
# Working on case 244 of 1093
# Working on case 245 of 1093
# Working on case 246 of 1093
# Working on case 247 of 1093
# Working on case 248 of 1093
# Working on case 249 of 1093
# Working on case 250 of 1093
# Working on case 251 of 1093
# Working on case 252 of 1093
# Working on case 253 of 1093
# Working on case 254 of 1093
# Working on case 255 of 1093
# Working on case 256 of 1093
# Working on case 257 of 1093
# Working on case 258 of 1093
# Working on case 259 of 1093
# Working on case 260 of 1093
# Working on case 261 of 1093
# Working on case 262 of 1093
# Working on case 263 of 1093
# Working on case 264 of 1093
# Working on case 265 of 1093
# Working on case 266 of 1093
# Working on case 267 of 1093
# Working on case 268 of 1093
# Working on case 269 of 1093
# Working on case 270 of 1093
# Working on case 271 of 1093
# Working on case 272 of 1093
# Working on case 273 of 1093
# Working on case 274 of 1093
# Working on case 275 of 1093
# Working on case 276 of 1093
# Working on case 277 of 1093
# Working on case 278 of 1093
# Working on case 279 of 1093
# Working on case 280 of 1093
# Working on case 281 of 1093
# Working on case 756 of 1093
# Working on case 757 of 1093
# Working on case 758 of 1093
# Working on case 759 of 1093
# Working on case 760 of 1093
# Working on case 761 of 1093
# Working on case 762 of 1093
# Working on case 763 of 1093
# Working on case 764 of 1093
# Working on case 765 of 1093
# Working on case 766 of 1093
# Working on case 767 of 1093
# Working on case 768 of 1093
# Working on case 769 of 1093
# Working on case 770 of 1093
# Working on case 771 of 1093
# Working on case 772 of 1093
# Working on case 773 of 1093
# Working on case 774 of 1093
# Working on case 775 of 1093
# Working on case 776 of 1093
# Working on case 777 of 1093
# Working on case 778 of 1093
# Working on case 779 of 1093
# Working on case 780 of 1093
# Working on case 781 of 1093
# Working on case 782 of 1093
# Working on case 783 of 1093
# Working on case 784 of 1093
# Working on case 785 of 1093
# Working on case 786 of 1093
# Working on case 787 of 1093
# Working on case 788 of 1093
# Working on case 789 of 1093
# Working on case 790 of 1093
# Working on case 791 of 1093
# Working on case 792 of 1093
# Working on case 793 of 1093
# Working on case 794 of 1093
# Working on case 795 of 1093
# Working on case 796 of 1093
# Working on case 797 of 1093
# Working on case 798 of 1093
# Working on case 799 of 1093
# Working on case 800 of 1093
# Working on case 801 of 1093
# Working on case 802 of 1093
# Working on case 803 of 1093
# Working on case 804 of 1093
# Working on case 805 of 1093
# Working on case 806 of 1093
# Working on case 807 of 1093
# Working on case 808 of 1093
# Working on case 809 of 1093
# Working on case 810 of 1093
# Working on case 811 of 1093
# Working on case 812 of 1093
# Working on case 813 of 1093
# Working on case 814 of 1093
# Working on case 815 of 1093
# Working on case 816 of 1093
# Working on case 817 of 1093
# Working on case 818 of 1093
# Working on case 819 of 1093
# Working on case 820 of 1093
# Working on case 821 of 1093
# Working on case 822 of 1093
# Working on case 823 of 1093
# Working on case 824 of 1093
# Working on case 825 of 1093
# Working on case 826 of 1093
# Working on case 827 of 1093
# Working on case 828 of 1093
# Working on case 829 of 1093
# Working on case 830 of 1093
# Working on case 831 of 1093
# Working on case 832 of 1093
# Working on case 833 of 1093
# Working on case 834 of 1093
# Working on case 835 of 1093
# Working on case 836 of 1093
# Working on case 837 of 1093
# Working on case 838 of 1093
# Working on case 839 of 1093
# Working on case 840 of 1093
# Working on case 841 of 1093
# Working on case 842 of 1093
# Working on case 843 of 1093
# Working on case 844 of 1093
# Working on case 845 of 1093
# Working on case 846 of 1093
# Working on case 847 of 1093
# Working on case 848 of 1093
# Working on case 849 of 1093
# Working on case 850 of 1093
# Working on case 851 of 1093
# Working on case 852 of 1093
# Working on case 853 of 1093
# Working on case 854 of 1093
# Working on case 855 of 1093
# Working on case 856 of 1093
# Working on case 857 of 1093
# Working on case 858 of 1093
# Working on case 859 of 1093
# Working on case 860 of 1093
# Working on case 861 of 1093
# Working on case 862 of 1093
# Working on case 863 of 1093
# Working on case 864 of 1093
# Working on case 865 of 1093
# Working on case 866 of 1093
# Working on case 867 of 1093
# Working on case 868 of 1093
# Working on case 869 of 1093
# Working on case 870 of 1093
# Working on case 871 of 1093
# Working on case 872 of 1093
# Working on case 873 of 1093
# Working on case 874 of 1093
# Working on case 875 of 1093
# Working on case 876 of 1093
# Working on case 877 of 1093
# Working on case 878 of 1093
# Working on case 879 of 1093
# Working on case 880 of 1093
# Working on case 881 of 1093
# Working on case 882 of 1093
# Working on case 883 of 1093
# Working on case 884 of 1093
# Working on case 885 of 1093
# Working on case 886 of 1093
# Working on case 887 of 1093
# Working on case 888 of 1093
# Working on case 889 of 1093
# Working on case 890 of 1093
# Working on case 891 of 1093
# Working on case 892 of 1093
# Working on case 893 of 1093
# Working on case 894 of 1093
# Working on case 895 of 1093
# Working on case 896 of 1093
# Working on case 897 of 1093
# Working on case 898 of 1093
# Working on case 899 of 1093
# Working on case 900 of 1093
# Working on case 901 of 1093
# Working on case 902 of 1093
# Working on case 903 of 1093
# Working on case 904 of 1093
# Working on case 905 of 1093
# Working on case 906 of 1093
# Working on case 907 of 1093
# Working on case 908 of 1093
# Working on case 909 of 1093
# Working on case 910 of 1093
# Working on case 911 of 1093
# Working on case 912 of 1093
# Working on case 913 of 1093
# Working on case 914 of 1093
# Working on case 915 of 1093
# Working on case 916 of 1093
# Working on case 917 of 1093
# Working on case 918 of 1093
# Working on case 919 of 1093
# Working on case 920 of 1093
# Working on case 921 of 1093
# Working on case 922 of 1093
# Working on case 923 of 1093
# Working on case 924 of 1093
# Working on case 925 of 1093
# Working on case 926 of 1093
# Working on case 927 of 1093
# Working on case 928 of 1093
# Working on case 929 of 1093
# Working on case 930 of 1093
# Working on case 931 of 1093
# Working on case 932 of 1093
# Working on case 933 of 1093
# Working on case 934 of 1093
# Working on case 935 of 1093
# Working on case 936 of 1093
# Working on case 937 of 1093
# Working on case 938 of 1093
# Working on case 939 of 1093
# Working on case 940 of 1093
# Working on case 941 of 1093
# Working on case 942 of 1093
# Working on case 943 of 1093
# Working on case 944 of 1093
# Working on case 945 of 1093
# Working on case 946 of 1093
# Working on case 947 of 1093
# Working on case 948 of 1093
# Working on case 949 of 1093
# Working on case 950 of 1093
# Working on case 951 of 1093
# Working on case 952 of 1093
# Working on case 953 of 1093
# Working on case 954 of 1093
# Working on case 955 of 1093
# Working on case 956 of 1093
# Working on case 957 of 1093
# Working on case 958 of 1093
# Working on case 959 of 1093
# Working on case 960 of 1093
# Working on case 961 of 1093
# Working on case 962 of 1093
# Working on case 963 of 1093
# Working on case 964 of 1093
# Working on case 965 of 1093
# Working on case 966 of 1093
# Working on case 967 of 1093
# Working on case 968 of 1093
# Working on case 969 of 1093
# Working on case 970 of 1093
# Working on case 971 of 1093
# Working on case 972 of 1093
# Working on case 973 of 1093
# Working on case 974 of 1093
# Working on case 975 of 1093
# Working on case 976 of 1093
# Working on case 977 of 1093
# Working on case 978 of 1093
# Working on case 979 of 1093
# Working on case 980 of 1093
# Working on case 981 of 1093
# Working on case 982 of 1093
# Working on case 983 of 1093
# Working on case 984 of 1093
# Working on case 985 of 1093
# Working on case 986 of 1093
# Working on case 987 of 1093
# Working on case 988 of 1093
# Working on case 989 of 1093
# Working on case 990 of 1093
# Working on case 991 of 1093
# Working on case 992 of 1093
# Working on case 993 of 1093
# Working on case 994 of 1093
# Working on case 995 of 1093
# Working on case 996 of 1093
# Working on case 997 of 1093
# Working on case 998 of 1093
# Working on case 999 of 1093
# Working on case 1000 of 1093
# Working on case 1001 of 1093
# Working on case 1002 of 1093
# Working on case 1003 of 1093
# Working on case 1004 of 1093
# Working on case 1005 of 1093
# Working on case 1006 of 1093
# Working on case 1007 of 1093
# Working on case 1008 of 1093
# Working on case 1009 of 1093
# Working on case 1010 of 1093
# Working on case 1011 of 1093
# Working on case 1012 of 1093
# Working on case 1013 of 1093
# Working on case 1014 of 1093
# Working on case 1015 of 1093
# Working on case 1016 of 1093
# Working on case 1017 of 1093
# Working on case 1018 of 1093
# Working on case 1019 of 1093
# Working on case 1020 of 1093
# Working on case 1021 of 1093
# Working on case 1022 of 1093
# Working on case 1023 of 1093
# Working on case 1024 of 1093
# Working on case 1025 of 1093
# Working on case 1026 of 1093
# Working on case 1027 of 1093
# Working on case 1028 of 1093
# Working on case 1029 of 1093
# Working on case 1030 of 1093
# Working on case 1031 of 1093
# Working on case 1032 of 1093
# Working on case 1033 of 1093
# Working on case 1034 of 1093
# Working on case 1035 of 1093
# Working on case 1036 of 1093
# Working on case 1037 of 1093
# Working on case 1038 of 1093
# Working on case 1039 of 1093
# Working on case 1040 of 1093
# Working on case 1041 of 1093
# Working on case 1042 of 1093
# Working on case 1043 of 1093
# Working on case 1044 of 1093
# Working on case 1045 of 1093
# Working on case 1046 of 1093
# Working on case 1047 of 1093
# Working on case 1048 of 1093
# Working on case 1049 of 1093
# Working on case 1050 of 1093
# Working on case 1051 of 1093
# Working on case 1052 of 1093
# Working on case 1053 of 1093
# Working on case 1054 of 1093
# Working on case 1055 of 1093
# Working on case 1056 of 1093
# Working on case 1057 of 1093
# Working on case 1058 of 1093
# Working on case 1059 of 1093
# Working on case 1060 of 1093
# Working on case 1061 of 1093
# Working on case 1062 of 1093
# Working on case 1063 of 1093
# Working on case 1064 of 1093
# Working on case 1065 of 1093
# Working on case 1066 of 1093
# Working on case 1067 of 1093
# Working on case 1068 of 1093
# Working on case 1069 of 1093
# Working on case 1070 of 1093
# Working on case 1071 of 1093
# Working on case 1072 of 1093
# Working on case 1073 of 1093
# Working on case 1074 of 1093
# Working on case 1075 of 1093
# Working on case 1076 of 1093
# Working on case 1077 of 1093
# Working on case 1078 of 1093
# Working on case 1079 of 1093
# Working on case 1080 of 1093
# Working on case 1081 of 1093
# Working on case 1082 of 1093
# Working on case 1083 of 1093
# Working on case 1084 of 1093
# Working on case 1085 of 1093
# Working on case 1086 of 1093
# Working on case 1087 of 1093
# Working on case 1088 of 1093
# Working on case 1089 of 1093
# Working on case 1090 of 1093
# Working on case 1091 of 1093
# Working on case 1092 of 1093
# Working on case 1093 of 1093

# %%
list( set([ clean_test_case['jsonData']['doc_category'] for clean_test_case in test_clean_metadata_list ]) )
# Out:
# ['',
#  'hspice',
#  'ibis',
#  'spice',
#  'thermal',
#  'system-verilog',
#  's-parameter',
#  'ibis-ami',
#  'verilog']
